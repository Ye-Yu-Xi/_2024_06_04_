# %%
#第一、二 程式區塊是複製14_1.ipynb

# %%
#寫程式下載檔案

import requests

url ="https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
r = requests.get(url)
if r.status_code == 200:                 
    print("下載成功")
#上面結果顯示200 代表連線成功、下載成功   # https://umbraco.com/knowledge-base/http-status-codes/
# Out:
# 下載成功

# %%
#json特性: 1.純文字 2.複雜的結構
# https://jsonviewer.stack.hu/   #把json資料貼到左邊的網址內/用view看
all_json = r.json()   #r.json type是dict
locations = all_json['cwaopendata']['dataset']['location']    #[key]這些都是json資料裡的   #['cwaopendata']['dataset']是dict   ['location'] 是list
weather_list = []
for item in locations:                          #for in裡的內容步驟：1.建立空的dict  2.
    city_item = {}
    city_item['城市'] = item['locationName']   
    city_item['起始時間'] = item['weatherElement'][1]['time'][0]['startTime'] 
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime'] 
    city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list     #依上述所看json是複雜的表格資料    #把資料過濾

# %%
import pandas as pd
weather_df = pd.DataFrame(weather_list)   #類別裡面可放list or dict
weather_df       #下方的結果 起始時間 是我下載的日期
# Out:
#      城市                       起始時間                       結束時間  最高溫度  最低溫度  \
# 0   臺北市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  25.0
# 1   新北市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  25.0
# 2   桃園市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  24.0
# 3   臺中市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  29.0  25.0
# 4   臺南市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  29.0  26.0
# 5   高雄市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  30.0  26.0
# 6   基隆市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  26.0  24.0
# 7   新竹縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  27.0  24.0
# 8   新竹市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  27.0  24.0
# 9   苗栗縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  27.0  24.0
# 10  彰化縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  25.0
# 11  南投縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  29.0  24.0
# 12  雲林縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  24.0
# 13  嘉義縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  24.0
# 14  嘉義市  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  24.0
# 15  屏東縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  30.0  25.0
# 16  宜蘭縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  27.0  24.0
# 17  花蓮縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  27.0  24.0
# 18  臺東縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  28.0  25.0
# 19  澎湖縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  26.0  25.0
# 20  金門縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  26.0  23.0
# 21  連江縣  2024-10-19T18:00:00+08:00  2024-10-20T06:00:00+08:00  23.0  21.0
#
#        感覺
# 0   舒適至悶熱
# 1   舒適至悶熱
# 2      舒適
# 3      舒適
# 4   舒適至悶熱
# 5   舒適至悶熱
# 6      舒適
# 7      舒適
# 8      舒適
# 9      舒適
# 10  舒適至悶熱
# 11  舒適至悶熱
# 12     舒適
# 13  舒適至悶熱
# 14  舒適至悶熱
# 15  舒適至悶熱
# 16  舒適至悶熱
# 17     舒適
# 18  舒適至悶熱
# 19     舒適
# 20     舒適
# 21     舒適
