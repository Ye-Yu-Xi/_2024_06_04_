# %%
#2:01:10
import numpy as np
import pandas as pd
import requests

url1 = 'https://ods.railway.gov.tw/tra-ods-web/ods/download/dataResource/8ae4cabf6973990e0169947ed32454b9'
response = requests.get(url1)   #2:08:00~2:09:40 #叫入JSON檔
jsonData = response.json()      #json轉成python資料結構
jsonData
# Out:
# [{'trnOpDate': '20240101',
#   'staCode': '0900',
#   'gateInComingCnt': '9613',
#   'gateOutGoingCnt': '10620'},
#  {'trnOpDate': '20240101',
#   'staCode': '0910',
#   'gateInComingCnt': '1254',
#   'gateOutGoingCnt': '1438'},
#  {'trnOpDate': '20240101',
#   'staCode': '0920',
#   'gateInComingCnt': '1685',
#   'gateOutGoingCnt': '1934'},
#  {'trnOpDate': '20240101',
#   'staCode': '0930',
#   'gateInComingCnt': '4718',
#   'gateOutGoingCnt': '5507'},
#  {'trnOpDate': '20240101',
#   'staCode': '0940',
#   'gateInComingCnt': '1737',
#   'gateOutGoingCnt': '2187'},
#  {'trnOpDate': '20240101',
#   'staCode': '0950',
#   'gateInComingCnt': '1552',
#   'gateOutGoingCnt': '1745'},
#  {'trnOpDate': '20240101',
#   'staCode': '0960',
#   'gateInComingCnt': '7909',
#   'gateOutGoingCnt': '9701'},
#  {'trnOpDate': '20240101',
#   'staCode': '0970',
#   'gateInComingCnt': '5299',
#   'gateOutGoingCnt': '6405'},
#  {'trnOpDate': '20240101',
#   'staCode': '0980',
#   'gateInComingCnt': '13571',
#   'gateOutGoingCnt': '12546'},
#  {'trnOpDate': '20240101',
#   'staCode': '0990',
#   'gateInComingCnt': '17270',
#   'gateOutGoingCnt': '15291'},
#  {'trnOpDate': '20240101',
#   'staCode': '1000',
#   'gateInComingCnt': '87019',
#   'gateOutGoingCnt': '70271'},
#  {'trnOpDate': '20240101',
#   'staCode': '1010',
#   'gateInComingCnt': '4352',
#   'gateOutGoingCnt': '4799'},
#  {'trnOpDate': '20240101',
#   'staCode': '1020',
#   'gateInComingCnt': '31611',
#   'gateOutGoingCnt': '30330'},
#  {'trnOpDate': '20240101',
#   'staCode': '1030',
#   'gateInComingCnt': '2282',
#   'gateOutGoingCnt': '2674'},
#  {'trnOpDate': '20240101',
#   'staCode': '1040',
#   'gateInComingCnt': '13565',
#   'gateOutGoingCnt': '16430'},
#  {'trnOpDate': '20240101',
#   'staCode': '1050',
#   'gateInComingCnt': '1111',
#   'gateOutGoingCnt': '1420'},
#  {'trnOpDate': '20240101',
#   'staCode': '1060',
#   'gateInComingCnt': '1568',
#   'gateOutGoingCnt': '1842'},
#  {'trnOpDate': '20240101',
#   'staCode': '1070',
#   'gateInComingCnt': '7930',
#   'gateOutGoingCnt': '8964'},
#  {'trnOpDate': '20240101',
#   'staCode': '1080',
#   'gateInComingCnt': '29562',
#   'gateOutGoingCnt': '35101'},
#  {'trnOpDate': '20240101',
#   'staCode': '1090',
#   'gateInComingCnt': '7668',
#   'gateOutGoingCnt': '10758'},
#  {'trnOpDate': '20240101',
#   'staCode': '1100',
#   'gateInComingCnt': '27922',
#   'gateOutGoingCnt': '34026'},
#  {'trnOpDate': '20240101',
#   'staCode': '1110',
#   'gateInComingCnt': '4930',
#   'gateOutGoingCnt': '6161'},
#  {'trnOpDate': '20240101',
#   'staCode': '1120',
#   'gateInComingCnt': '4267',
#   'gateOutGoingCnt': '5789'},
#  {'trnOpDate': '20240101',
#   'staCode': '1130',
#   'gateInComingCnt': '1790',
#   'gateOutGoingCnt': '2056'},
#  {'trnOpDate': '20240101',
#   'staCode': '1140',
#   'gateInComingCnt': '246',
#   'gateOutGoingCnt': '270'},
#  {'trnOpDate': '20240101',
#   'staCode': '1150',
#   'gateInComingCnt': '622',
#   'gateOutGoingCnt': '849'},
#  {'trnOpDate': '20240101',
#   'staCode': '1160',
#   'gateInComingCnt': '3400',
#   'gateOutGoingCnt': '4155'},
#  {'trnOpDate': '20240101',
#   'staCode': '1170',
#   'gateInComingCnt': '6040',
#   'gateOutGoingCnt': '9421'},
#  {'trnOpDate': '20240101',
#   'staCode': '1180',
#   'gateInComingCnt': '4742',
#   'gateOutGoingCnt': '5717'},
#  {'trnOpDate': '20240101',
#   'staCode': '1190',
#   'gateInComingCnt': '1766',
#   'gateOutGoingCnt': '2220'},
#  {'trnOpDate': '20240101',
#   'staCode': '1191',
#   'gateInComingCnt': '275',
#   'gateOutGoingCnt': '356'},
#  {'trnOpDate': '20240101',
#   'staCode': '1192',
#   'gateInComingCnt': '1423',
#   'gateOutGoingCnt': '3285'},
#  {'trnOpDate': '20240101',
#   'staCode': '1193',
#   'gateInComingCnt': '773',
#   'gateOutGoingCnt': '1446'},
#  {'trnOpDate': '20240101',
#   'staCode': '1194',
#   'gateInComingCnt': '5986',
#   'gateOutGoingCnt': '2895'},
#  {'trnOpDate': '20240101',
#   'staCode': '1201',
#   'gateInComingCnt': '87',
#   'gateOutGoingCnt': '85'},
#  {'trnOpDate': '20240101',
#   'staCode': '1202',
#   'gateInComingCnt': '2240',
#   'gateOutGoingCnt': '247'},
#  {'trnOpDate': '20240101',
#   'staCode': '1203',
#   'gateInComingCnt': '631',
#   'gateOutGoingCnt': '666'},
#  {'trnOpDate': '20240101',
#   'staCode': '1204',
#   'gateInComingCnt': '113',
#   'gateOutGoingCnt': '102'},
#  {'trnOpDate': '20240101',
#   'staCode': '1205',
#   'gateInComingCnt': '65',
#   'gateOutGoingCnt': '71'},
#  {'trnOpDate': '20240101',
#   'staCode': '1206',
#   'gateInComingCnt': '163',
#   'gateOutGoingCnt': '302'},
#  {'trnOpDate': '20240101',
#   'staCode': '1207',
#   'gateInComingCnt': '108',
#   'gateOutGoingCnt': '2114'},
#  {'trnOpDate': '20240101',
#   'staCode': '1208',
#   'gateInComingCnt': '1320',
#   'gateOutGoingCnt': '1212'},
#  {'trnOpDate': '20240101',
#   'staCode': '1210',
#   'gateInComingCnt': '24603',
#   'gateOutGoingCnt': '27698'},
#  {'trnOpDate': '20240101',
#   'staCode': '1220',
#   'gateInComingCnt': '977',
#   'gateOutGoingCnt': '1386'},
#  {'trnOpDate': '20240101',
#   'staCode': '1230',
#   'gateInComingCnt': '601',
#   'gateOutGoingCnt': '605'},
#  {'trnOpDate': '20240101',
#   'staCode': '1240',
#   'gateInComingCnt': '258',
#   'gateOutGoingCnt': '281'},
#  {'trnOpDate': '20240101',
#   'staCode': '1250',
#   'gateInComingCnt': '9513',
#   'gateOutGoingCnt': '10393'},
#  {'trnOpDate': '20240101',
#   'staCode': '2110',
#   'gateInComingCnt': '50',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20240101',
#   'staCode': '2120',
#   'gateInComingCnt': '69',
#   'gateOutGoingCnt': '70'},
#  {'trnOpDate': '20240101',
#   'staCode': '2130',
#   'gateInComingCnt': '852',
#   'gateOutGoingCnt': '1792'},
#  {'trnOpDate': '20240101',
#   'staCode': '2140',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20240101',
#   'staCode': '2150',
#   'gateInComingCnt': '1231',
#   'gateOutGoingCnt': '1135'},
#  {'trnOpDate': '20240101',
#   'staCode': '2160',
#   'gateInComingCnt': '80',
#   'gateOutGoingCnt': '57'},
#  {'trnOpDate': '20240101',
#   'staCode': '2170',
#   'gateInComingCnt': '1117',
#   'gateOutGoingCnt': '826'},
#  {'trnOpDate': '20240101',
#   'staCode': '2180',
#   'gateInComingCnt': '1811',
#   'gateOutGoingCnt': '1581'},
#  {'trnOpDate': '20240101',
#   'staCode': '2190',
#   'gateInComingCnt': '401',
#   'gateOutGoingCnt': '392'},
#  {'trnOpDate': '20240101',
#   'staCode': '2200',
#   'gateInComingCnt': '4374',
#   'gateOutGoingCnt': '3814'},
#  {'trnOpDate': '20240101',
#   'staCode': '2210',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '88'},
#  {'trnOpDate': '20240101',
#   'staCode': '2220',
#   'gateInComingCnt': '2020',
#   'gateOutGoingCnt': '1523'},
#  {'trnOpDate': '20240101',
#   'staCode': '2230',
#   'gateInComingCnt': '4196',
#   'gateOutGoingCnt': '4596'},
#  {'trnOpDate': '20240101',
#   'staCode': '2240',
#   'gateInComingCnt': '731',
#   'gateOutGoingCnt': '650'},
#  {'trnOpDate': '20240101',
#   'staCode': '2250',
#   'gateInComingCnt': '2320',
#   'gateOutGoingCnt': '867'},
#  {'trnOpDate': '20240101',
#   'staCode': '2260',
#   'gateInComingCnt': '9730',
#   'gateOutGoingCnt': '2224'},
#  {'trnOpDate': '20240101',
#   'staCode': '3140',
#   'gateInComingCnt': '370',
#   'gateOutGoingCnt': '376'},
#  {'trnOpDate': '20240101',
#   'staCode': '3150',
#   'gateInComingCnt': '1716',
#   'gateOutGoingCnt': '1115'},
#  {'trnOpDate': '20240101',
#   'staCode': '3160',
#   'gateInComingCnt': '5937',
#   'gateOutGoingCnt': '6445'},
#  {'trnOpDate': '20240101',
#   'staCode': '3170',
#   'gateInComingCnt': '108',
#   'gateOutGoingCnt': '175'},
#  {'trnOpDate': '20240101',
#   'staCode': '3180',
#   'gateInComingCnt': '1183',
#   'gateOutGoingCnt': '1185'},
#  {'trnOpDate': '20240101',
#   'staCode': '3190',
#   'gateInComingCnt': '903',
#   'gateOutGoingCnt': '758'},
#  {'trnOpDate': '20240101',
#   'staCode': '3210',
#   'gateInComingCnt': '830',
#   'gateOutGoingCnt': '674'},
#  {'trnOpDate': '20240101',
#   'staCode': '3220',
#   'gateInComingCnt': '2789',
#   'gateOutGoingCnt': '2903'},
#  {'trnOpDate': '20240101',
#   'staCode': '3230',
#   'gateInComingCnt': '11541',
#   'gateOutGoingCnt': '10722'},
#  {'trnOpDate': '20240101',
#   'staCode': '3240',
#   'gateInComingCnt': '991',
#   'gateOutGoingCnt': '993'},
#  {'trnOpDate': '20240101',
#   'staCode': '3250',
#   'gateInComingCnt': '2886',
#   'gateOutGoingCnt': '3072'},
#  {'trnOpDate': '20240101',
#   'staCode': '3260',
#   'gateInComingCnt': '812',
#   'gateOutGoingCnt': '752'},
#  {'trnOpDate': '20240101',
#   'staCode': '3270',
#   'gateInComingCnt': '3793',
#   'gateOutGoingCnt': '2873'},
#  {'trnOpDate': '20240101',
#   'staCode': '3280',
#   'gateInComingCnt': '2682',
#   'gateOutGoingCnt': '2581'},
#  {'trnOpDate': '20240101',
#   'staCode': '3290',
#   'gateInComingCnt': '1744',
#   'gateOutGoingCnt': '2000'},
#  {'trnOpDate': '20240101',
#   'staCode': '3300',
#   'gateInComingCnt': '42902',
#   'gateOutGoingCnt': '42427'},
#  {'trnOpDate': '20240101',
#   'staCode': '3310',
#   'gateInComingCnt': '1725',
#   'gateOutGoingCnt': '2053'},
#  {'trnOpDate': '20240101',
#   'staCode': '3320',
#   'gateInComingCnt': '3388',
#   'gateOutGoingCnt': '3209'},
#  {'trnOpDate': '20240101',
#   'staCode': '3330',
#   'gateInComingCnt': '935',
#   'gateOutGoingCnt': '1000'},
#  {'trnOpDate': '20240101',
#   'staCode': '3340',
#   'gateInComingCnt': '13140',
#   'gateOutGoingCnt': '12456'},
#  {'trnOpDate': '20240101',
#   'staCode': '3350',
#   'gateInComingCnt': '2657',
#   'gateOutGoingCnt': '11707'},
#  {'trnOpDate': '20240101',
#   'staCode': '3360',
#   'gateInComingCnt': '17907',
#   'gateOutGoingCnt': '19253'},
#  {'trnOpDate': '20240101',
#   'staCode': '3370',
#   'gateInComingCnt': '1604',
#   'gateOutGoingCnt': '1503'},
#  {'trnOpDate': '20240101',
#   'staCode': '3380',
#   'gateInComingCnt': '964',
#   'gateOutGoingCnt': '1135'},
#  {'trnOpDate': '20240101',
#   'staCode': '3390',
#   'gateInComingCnt': '9811',
#   'gateOutGoingCnt': '8474'},
#  {'trnOpDate': '20240101',
#   'staCode': '3400',
#   'gateInComingCnt': '849',
#   'gateOutGoingCnt': '592'},
#  {'trnOpDate': '20240101',
#   'staCode': '3410',
#   'gateInComingCnt': '1274',
#   'gateOutGoingCnt': '1206'},
#  {'trnOpDate': '20240101',
#   'staCode': '3420',
#   'gateInComingCnt': '3418',
#   'gateOutGoingCnt': '2683'},
#  {'trnOpDate': '20240101',
#   'staCode': '3430',
#   'gateInComingCnt': '1569',
#   'gateOutGoingCnt': '1261'},
#  {'trnOpDate': '20240101',
#   'staCode': '3431',
#   'gateInComingCnt': '21',
#   'gateOutGoingCnt': '126'},
#  {'trnOpDate': '20240101',
#   'staCode': '3432',
#   'gateInComingCnt': '142',
#   'gateOutGoingCnt': '232'},
#  {'trnOpDate': '20240101',
#   'staCode': '3433',
#   'gateInComingCnt': '23',
#   'gateOutGoingCnt': '185'},
#  {'trnOpDate': '20240101',
#   'staCode': '3434',
#   'gateInComingCnt': '1338',
#   'gateOutGoingCnt': '414'},
#  {'trnOpDate': '20240101',
#   'staCode': '3435',
#   'gateInComingCnt': '138',
#   'gateOutGoingCnt': '252'},
#  {'trnOpDate': '20240101',
#   'staCode': '3436',
#   'gateInComingCnt': '234',
#   'gateOutGoingCnt': '346'},
#  {'trnOpDate': '20240101',
#   'staCode': '3450',
#   'gateInComingCnt': '1136',
#   'gateOutGoingCnt': '805'},
#  {'trnOpDate': '20240101',
#   'staCode': '3460',
#   'gateInComingCnt': '303',
#   'gateOutGoingCnt': '267'},
#  {'trnOpDate': '20240101',
#   'staCode': '3470',
#   'gateInComingCnt': '8343',
#   'gateOutGoingCnt': '8995'},
#  {'trnOpDate': '20240101',
#   'staCode': '3480',
#   'gateInComingCnt': '3125',
#   'gateOutGoingCnt': '2935'},
#  {'trnOpDate': '20240101',
#   'staCode': '3490',
#   'gateInComingCnt': '199',
#   'gateOutGoingCnt': '144'},
#  {'trnOpDate': '20240101',
#   'staCode': '4050',
#   'gateInComingCnt': '1750',
#   'gateOutGoingCnt': '2679'},
#  {'trnOpDate': '20240101',
#   'staCode': '4060',
#   'gateInComingCnt': '2147',
#   'gateOutGoingCnt': '3729'},
#  {'trnOpDate': '20240101',
#   'staCode': '4070',
#   'gateInComingCnt': '733',
#   'gateOutGoingCnt': '674'},
#  {'trnOpDate': '20240101',
#   'staCode': '4080',
#   'gateInComingCnt': '15071',
#   'gateOutGoingCnt': '14287'},
#  {'trnOpDate': '20240101',
#   'staCode': '4090',
#   'gateInComingCnt': '921',
#   'gateOutGoingCnt': '808'},
#  {'trnOpDate': '20240101',
#   'staCode': '4100',
#   'gateInComingCnt': '335',
#   'gateOutGoingCnt': '214'},
#  {'trnOpDate': '20240101',
#   'staCode': '4110',
#   'gateInComingCnt': '683',
#   'gateOutGoingCnt': '590'},
#  {'trnOpDate': '20240101',
#   'staCode': '4120',
#   'gateInComingCnt': '6190',
#   'gateOutGoingCnt': '5199'},
#  {'trnOpDate': '20240101',
#   'staCode': '4130',
#   'gateInComingCnt': '417',
#   'gateOutGoingCnt': '1000'},
#  {'trnOpDate': '20240101',
#   'staCode': '4140',
#   'gateInComingCnt': '593',
#   'gateOutGoingCnt': '495'},
#  {'trnOpDate': '20240101',
#   'staCode': '4150',
#   'gateInComingCnt': '1187',
#   'gateOutGoingCnt': '1611'},
#  {'trnOpDate': '20240101',
#   'staCode': '4160',
#   'gateInComingCnt': '157',
#   'gateOutGoingCnt': '169'},
#  {'trnOpDate': '20240101',
#   'staCode': '4170',
#   'gateInComingCnt': '3318',
#   'gateOutGoingCnt': '4069'},
#  {'trnOpDate': '20240101',
#   'staCode': '4180',
#   'gateInComingCnt': '802',
#   'gateOutGoingCnt': '1401'},
#  {'trnOpDate': '20240101',
#   'staCode': '4190',
#   'gateInComingCnt': '2120',
#   'gateOutGoingCnt': '2943'},
#  {'trnOpDate': '20240101',
#   'staCode': '4200',
#   'gateInComingCnt': '14583',
#   'gateOutGoingCnt': '7405'},
#  {'trnOpDate': '20240101',
#   'staCode': '4210',
#   'gateInComingCnt': '2543',
#   'gateOutGoingCnt': '4425'},
#  {'trnOpDate': '20240101',
#   'staCode': '4220',
#   'gateInComingCnt': '35408',
#   'gateOutGoingCnt': '34278'},
#  {'trnOpDate': '20240101',
#   'staCode': '4250',
#   'gateInComingCnt': '4361',
#   'gateOutGoingCnt': '14038'},
#  {'trnOpDate': '20240101',
#   'staCode': '4260',
#   'gateInComingCnt': '889',
#   'gateOutGoingCnt': '1249'},
#  {'trnOpDate': '20240101',
#   'staCode': '4270',
#   'gateInComingCnt': '414',
#   'gateOutGoingCnt': '574'},
#  {'trnOpDate': '20240101',
#   'staCode': '4271',
#   'gateInComingCnt': '278',
#   'gateOutGoingCnt': '876'},
#  {'trnOpDate': '20240101',
#   'staCode': '4272',
#   'gateInComingCnt': '6184',
#   'gateOutGoingCnt': '5851'},
#  {'trnOpDate': '20240101',
#   'staCode': '4290',
#   'gateInComingCnt': '996',
#   'gateOutGoingCnt': '1221'},
#  {'trnOpDate': '20240101',
#   'staCode': '4300',
#   'gateInComingCnt': '1455',
#   'gateOutGoingCnt': '1692'},
#  {'trnOpDate': '20240101',
#   'staCode': '4310',
#   'gateInComingCnt': '3219',
#   'gateOutGoingCnt': '3710'},
#  {'trnOpDate': '20240101',
#   'staCode': '4320',
#   'gateInComingCnt': '1824',
#   'gateOutGoingCnt': '1777'},
#  {'trnOpDate': '20240101',
#   'staCode': '4330',
#   'gateInComingCnt': '2417',
#   'gateOutGoingCnt': '3220'},
#  {'trnOpDate': '20240101',
#   'staCode': '4340',
#   'gateInComingCnt': '18484',
#   'gateOutGoingCnt': '20682'},
#  {'trnOpDate': '20240101',
#   'staCode': '4350',
#   'gateInComingCnt': '839',
#   'gateOutGoingCnt': '846'},
#  {'trnOpDate': '20240101',
#   'staCode': '4360',
#   'gateInComingCnt': '791',
#   'gateOutGoingCnt': '770'},
#  {'trnOpDate': '20240101',
#   'staCode': '4370',
#   'gateInComingCnt': '1327',
#   'gateOutGoingCnt': '1336'},
#  {'trnOpDate': '20240101',
#   'staCode': '4380',
#   'gateInComingCnt': '770',
#   'gateOutGoingCnt': '747'},
#  {'trnOpDate': '20240101',
#   'staCode': '4390',
#   'gateInComingCnt': '702',
#   'gateOutGoingCnt': '662'},
#  {'trnOpDate': '20240101',
#   'staCode': '4400',
#   'gateInComingCnt': '22059',
#   'gateOutGoingCnt': '18388'},
#  {'trnOpDate': '20240101',
#   'staCode': '4410',
#   'gateInComingCnt': '828',
#   'gateOutGoingCnt': '888'},
#  {'trnOpDate': '20240101',
#   'staCode': '4420',
#   'gateInComingCnt': '1750',
#   'gateOutGoingCnt': '1705'},
#  {'trnOpDate': '20240101',
#   'staCode': '4430',
#   'gateInComingCnt': '1147',
#   'gateOutGoingCnt': '1254'},
#  {'trnOpDate': '20240101',
#   'staCode': '4440',
#   'gateInComingCnt': '7146',
#   'gateOutGoingCnt': '7920'},
#  {'trnOpDate': '20240101',
#   'staCode': '4450',
#   'gateInComingCnt': '672',
#   'gateOutGoingCnt': '677'},
#  {'trnOpDate': '20240101',
#   'staCode': '4460',
#   'gateInComingCnt': '1258',
#   'gateOutGoingCnt': '1387'},
#  {'trnOpDate': '20240101',
#   'staCode': '4470',
#   'gateInComingCnt': '93',
#   'gateOutGoingCnt': '99'},
#  {'trnOpDate': '20240101',
#   'staCode': '5000',
#   'gateInComingCnt': '13796',
#   'gateOutGoingCnt': '14055'},
#  {'trnOpDate': '20240101',
#   'staCode': '5010',
#   'gateInComingCnt': '284',
#   'gateOutGoingCnt': '347'},
#  {'trnOpDate': '20240101',
#   'staCode': '5020',
#   'gateInComingCnt': '262',
#   'gateOutGoingCnt': '212'},
#  {'trnOpDate': '20240101',
#   'staCode': '5030',
#   'gateInComingCnt': '1005',
#   'gateOutGoingCnt': '997'},
#  {'trnOpDate': '20240101',
#   'staCode': '5040',
#   'gateInComingCnt': '351',
#   'gateOutGoingCnt': '342'},
#  {'trnOpDate': '20240101',
#   'staCode': '5050',
#   'gateInComingCnt': '5861',
#   'gateOutGoingCnt': '4974'},
#  {'trnOpDate': '20240101',
#   'staCode': '5060',
#   'gateInComingCnt': '56',
#   'gateOutGoingCnt': '55'},
#  {'trnOpDate': '20240101',
#   'staCode': '5070',
#   'gateInComingCnt': '620',
#   'gateOutGoingCnt': '717'},
#  {'trnOpDate': '20240101',
#   'staCode': '5080',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20240101',
#   'staCode': '5090',
#   'gateInComingCnt': '735',
#   'gateOutGoingCnt': '505'},
#  {'trnOpDate': '20240101',
#   'staCode': '5100',
#   'gateInComingCnt': '212',
#   'gateOutGoingCnt': '130'},
#  {'trnOpDate': '20240101',
#   'staCode': '5110',
#   'gateInComingCnt': '83',
#   'gateOutGoingCnt': '388'},
#  {'trnOpDate': '20240101',
#   'staCode': '5120',
#   'gateInComingCnt': '2108',
#   'gateOutGoingCnt': '1511'},
#  {'trnOpDate': '20240101',
#   'staCode': '5130',
#   'gateInComingCnt': '321',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20240101',
#   'staCode': '5140',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240101',
#   'staCode': '5160',
#   'gateInComingCnt': '16',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240101',
#   'staCode': '5190',
#   'gateInComingCnt': '320',
#   'gateOutGoingCnt': '243'},
#  {'trnOpDate': '20240101',
#   'staCode': '5200',
#   'gateInComingCnt': '54',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20240101',
#   'staCode': '5210',
#   'gateInComingCnt': '659',
#   'gateOutGoingCnt': '420'},
#  {'trnOpDate': '20240101',
#   'staCode': '5220',
#   'gateInComingCnt': '454',
#   'gateOutGoingCnt': '261'},
#  {'trnOpDate': '20240101',
#   'staCode': '5230',
#   'gateInComingCnt': '1275',
#   'gateOutGoingCnt': '1286'},
#  {'trnOpDate': '20240101',
#   'staCode': '5240',
#   'gateInComingCnt': '30',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20240101',
#   'staCode': '6000',
#   'gateInComingCnt': '16737',
#   'gateOutGoingCnt': '8157'},
#  {'trnOpDate': '20240101',
#   'staCode': '6010',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20240101',
#   'staCode': '6020',
#   'gateInComingCnt': '331',
#   'gateOutGoingCnt': '183'},
#  {'trnOpDate': '20240101',
#   'staCode': '6030',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20240101',
#   'staCode': '6040',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20240101',
#   'staCode': '6050',
#   'gateInComingCnt': '950',
#   'gateOutGoingCnt': '603'},
#  {'trnOpDate': '20240101',
#   'staCode': '6060',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '5'},
#  {'trnOpDate': '20240101',
#   'staCode': '6070',
#   'gateInComingCnt': '1178',
#   'gateOutGoingCnt': '592'},
#  {'trnOpDate': '20240101',
#   'staCode': '6080',
#   'gateInComingCnt': '303',
#   'gateOutGoingCnt': '184'},
#  {'trnOpDate': '20240101',
#   'staCode': '6090',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '27'},
#  {'trnOpDate': '20240101',
#   'staCode': '6100',
#   'gateInComingCnt': '21',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20240101',
#   'staCode': '6110',
#   'gateInComingCnt': '2255',
#   'gateOutGoingCnt': '1661'},
#  {'trnOpDate': '20240101',
#   'staCode': '6120',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '23'},
#  {'trnOpDate': '20240101',
#   'staCode': '6130',
#   'gateInComingCnt': '1572',
#   'gateOutGoingCnt': '624'},
#  {'trnOpDate': '20240101',
#   'staCode': '6140',
#   'gateInComingCnt': '52',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20240101',
#   'staCode': '6150',
#   'gateInComingCnt': '25',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20240101',
#   'staCode': '6160',
#   'gateInComingCnt': '688',
#   'gateOutGoingCnt': '796'},
#  {'trnOpDate': '20240101',
#   'staCode': '6170',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '43'},
#  {'trnOpDate': '20240101',
#   'staCode': '6180',
#   'gateInComingCnt': '436',
#   'gateOutGoingCnt': '327'},
#  {'trnOpDate': '20240101',
#   'staCode': '6190',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20240101',
#   'staCode': '6200',
#   'gateInComingCnt': '73',
#   'gateOutGoingCnt': '59'},
#  {'trnOpDate': '20240101',
#   'staCode': '6210',
#   'gateInComingCnt': '48',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20240101',
#   'staCode': '6220',
#   'gateInComingCnt': '504',
#   'gateOutGoingCnt': '647'},
#  {'trnOpDate': '20240101',
#   'staCode': '6230',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20240101',
#   'staCode': '6240',
#   'gateInComingCnt': '268',
#   'gateOutGoingCnt': '1435'},
#  {'trnOpDate': '20240101',
#   'staCode': '6250',
#   'gateInComingCnt': '874',
#   'gateOutGoingCnt': '710'},
#  {'trnOpDate': '20240101',
#   'staCode': '7000',
#   'gateInComingCnt': '23901',
#   'gateOutGoingCnt': '16369'},
#  {'trnOpDate': '20240101',
#   'staCode': '7010',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '137'},
#  {'trnOpDate': '20240101',
#   'staCode': '7020',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20240101',
#   'staCode': '7030',
#   'gateInComingCnt': '754',
#   'gateOutGoingCnt': '689'},
#  {'trnOpDate': '20240101',
#   'staCode': '7040',
#   'gateInComingCnt': '42',
#   'gateOutGoingCnt': '33'},
#  {'trnOpDate': '20240101',
#   'staCode': '7050',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20240101',
#   'staCode': '7060',
#   'gateInComingCnt': '677',
#   'gateOutGoingCnt': '540'},
#  {'trnOpDate': '20240101',
#   'staCode': '7070',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20240101',
#   'staCode': '7080',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20240101',
#   'staCode': '7090',
#   'gateInComingCnt': '843',
#   'gateOutGoingCnt': '556'},
#  {'trnOpDate': '20240101',
#   'staCode': '7100',
#   'gateInComingCnt': '195',
#   'gateOutGoingCnt': '115'},
#  {'trnOpDate': '20240101',
#   'staCode': '7110',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240101',
#   'staCode': '7120',
#   'gateInComingCnt': '560',
#   'gateOutGoingCnt': '600'},
#  {'trnOpDate': '20240101',
#   'staCode': '7130',
#   'gateInComingCnt': '662',
#   'gateOutGoingCnt': '707'},
#  {'trnOpDate': '20240101',
#   'staCode': '7150',
#   'gateInComingCnt': '588',
#   'gateOutGoingCnt': '568'},
#  {'trnOpDate': '20240101',
#   'staCode': '7160',
#   'gateInComingCnt': '7885',
#   'gateOutGoingCnt': '7432'},
#  {'trnOpDate': '20240101',
#   'staCode': '7170',
#   'gateInComingCnt': '61',
#   'gateOutGoingCnt': '66'},
#  {'trnOpDate': '20240101',
#   'staCode': '7180',
#   'gateInComingCnt': '182',
#   'gateOutGoingCnt': '161'},
#  {'trnOpDate': '20240101',
#   'staCode': '7190',
#   'gateInComingCnt': '6520',
#   'gateOutGoingCnt': '6293'},
#  {'trnOpDate': '20240101',
#   'staCode': '7200',
#   'gateInComingCnt': '172',
#   'gateOutGoingCnt': '135'},
#  {'trnOpDate': '20240101',
#   'staCode': '7210',
#   'gateInComingCnt': '3747',
#   'gateOutGoingCnt': '3003'},
#  {'trnOpDate': '20240101',
#   'staCode': '7220',
#   'gateInComingCnt': '77',
#   'gateOutGoingCnt': '84'},
#  {'trnOpDate': '20240101',
#   'staCode': '7230',
#   'gateInComingCnt': '1401',
#   'gateOutGoingCnt': '1077'},
#  {'trnOpDate': '20240101',
#   'staCode': '7240',
#   'gateInComingCnt': '222',
#   'gateOutGoingCnt': '192'},
#  {'trnOpDate': '20240101',
#   'staCode': '7250',
#   'gateInComingCnt': '105',
#   'gateOutGoingCnt': '77'},
#  {'trnOpDate': '20240101',
#   'staCode': '7260',
#   'gateInComingCnt': '259',
#   'gateOutGoingCnt': '243'},
#  {'trnOpDate': '20240101',
#   'staCode': '7270',
#   'gateInComingCnt': '548',
#   'gateOutGoingCnt': '389'},
#  {'trnOpDate': '20240101',
#   'staCode': '7280',
#   'gateInComingCnt': '35',
#   'gateOutGoingCnt': '30'},
#  {'trnOpDate': '20240101',
#   'staCode': '7290',
#   'gateInComingCnt': '1328',
#   'gateOutGoingCnt': '1136'},
#  {'trnOpDate': '20240101',
#   'staCode': '7300',
#   'gateInComingCnt': '143',
#   'gateOutGoingCnt': '172'},
#  {'trnOpDate': '20240101',
#   'staCode': '7310',
#   'gateInComingCnt': '658',
#   'gateOutGoingCnt': '613'},
#  {'trnOpDate': '20240101',
#   'staCode': '7320',
#   'gateInComingCnt': '267',
#   'gateOutGoingCnt': '410'},
#  {'trnOpDate': '20240101',
#   'staCode': '7330',
#   'gateInComingCnt': '460',
#   'gateOutGoingCnt': '279'},
#  {'trnOpDate': '20240101',
#   'staCode': '7331',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20240101',
#   'staCode': '7332',
#   'gateInComingCnt': '2297',
#   'gateOutGoingCnt': '2275'},
#  {'trnOpDate': '20240101',
#   'staCode': '7333',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20240101',
#   'staCode': '7334',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20240101',
#   'staCode': '7335',
#   'gateInComingCnt': '561',
#   'gateOutGoingCnt': '532'},
#  {'trnOpDate': '20240101',
#   'staCode': '7336',
#   'gateInComingCnt': '530',
#   'gateOutGoingCnt': '490'},
#  {'trnOpDate': '20240101',
#   'staCode': '7350',
#   'gateInComingCnt': '1550',
#   'gateOutGoingCnt': '1575'},
#  {'trnOpDate': '20240101',
#   'staCode': '7360',
#   'gateInComingCnt': '6145',
#   'gateOutGoingCnt': '6874'},
#  {'trnOpDate': '20240101',
#   'staCode': '7361',
#   'gateInComingCnt': '102',
#   'gateOutGoingCnt': '123'},
#  {'trnOpDate': '20240101',
#   'staCode': '7362',
#   'gateInComingCnt': '325',
#   'gateOutGoingCnt': '326'},
#  {'trnOpDate': '20240101',
#   'staCode': '7380',
#   'gateInComingCnt': '550',
#   'gateOutGoingCnt': '617'},
#  {'trnOpDate': '20240101',
#   'staCode': '7390',
#   'gateInComingCnt': '414',
#   'gateOutGoingCnt': '468'},
#  {'trnOpDate': '20240102',
#   'staCode': '0900',
#   'gateInComingCnt': '9172',
#   'gateOutGoingCnt': '8784'},
#  {'trnOpDate': '20240102',
#   'staCode': '0910',
#   'gateInComingCnt': '1557',
#   'gateOutGoingCnt': '1633'},
#  {'trnOpDate': '20240102',
#   'staCode': '0920',
#   'gateInComingCnt': '2718',
#   'gateOutGoingCnt': '2463'},
#  {'trnOpDate': '20240102',
#   'staCode': '0930',
#   'gateInComingCnt': '6866',
#   'gateOutGoingCnt': '6779'},
#  {'trnOpDate': '20240102',
#   'staCode': '0940',
#   'gateInComingCnt': '2917',
#   'gateOutGoingCnt': '2959'},
#  {'trnOpDate': '20240102',
#   'staCode': '0950',
#   'gateInComingCnt': '2670',
#   'gateOutGoingCnt': '2149'},
#  {'trnOpDate': '20240102',
#   'staCode': '0960',
#   'gateInComingCnt': '11772',
#   'gateOutGoingCnt': '12507'},
#  {'trnOpDate': '20240102',
#   'staCode': '0970',
#   'gateInComingCnt': '13824',
#   'gateOutGoingCnt': '14139'},
#  {'trnOpDate': '20240102',
#   'staCode': '0980',
#   'gateInComingCnt': '15883',
#   'gateOutGoingCnt': '16399'},
#  {'trnOpDate': '20240102',
#   'staCode': '0990',
#   'gateInComingCnt': '19833',
#   'gateOutGoingCnt': '20275'},
#  {'trnOpDate': '20240102',
#   'staCode': '1000',
#   'gateInComingCnt': '61789',
#   'gateOutGoingCnt': '64232'},
#  {'trnOpDate': '20240102',
#   'staCode': '1010',
#   'gateInComingCnt': '5289',
#   'gateOutGoingCnt': '5269'},
#  {'trnOpDate': '20240102',
#   'staCode': '1020',
#   'gateInComingCnt': '23852',
#   'gateOutGoingCnt': '24700'},
#  {'trnOpDate': '20240102',
#   'staCode': '1030',
#   'gateInComingCnt': '3725',
#   'gateOutGoingCnt': '3775'},
#  {'trnOpDate': '20240102',
#   'staCode': '1040',
#   'gateInComingCnt': '14659',
#   'gateOutGoingCnt': '14863'},
#  {'trnOpDate': '20240102',
#   'staCode': '1050',
#   'gateInComingCnt': '1443',
#   'gateOutGoingCnt': '1413'},
#  {'trnOpDate': '20240102',
#   'staCode': '1060',
#   'gateInComingCnt': '1779',
#   'gateOutGoingCnt': '1768'},
#  {'trnOpDate': '20240102',
#   'staCode': '1070',
#   'gateInComingCnt': '9124',
#   'gateOutGoingCnt': '9292'},
#  {'trnOpDate': '20240102',
#   'staCode': '1080',
#   'gateInComingCnt': '27189',
#   'gateOutGoingCnt': '28245'},
#  {'trnOpDate': '20240102',
#   'staCode': '1090',
#   'gateInComingCnt': '10323',
#   'gateOutGoingCnt': '10257'},
#  {'trnOpDate': '20240102',
#   'staCode': '1100',
#   'gateInComingCnt': '23022',
#   'gateOutGoingCnt': '24894'},
#  {'trnOpDate': '20240102',
#   'staCode': '1110',
#   'gateInComingCnt': '6423',
#   'gateOutGoingCnt': '6164'},
#  {'trnOpDate': '20240102',
#   'staCode': '1120',
#   'gateInComingCnt': '5346',
#   'gateOutGoingCnt': '4958'},
#  {'trnOpDate': '20240102',
#   'staCode': '1130',
#   'gateInComingCnt': '1787',
#   'gateOutGoingCnt': '1747'},
#  {'trnOpDate': '20240102',
#   'staCode': '1140',
#   'gateInComingCnt': '358',
#   'gateOutGoingCnt': '347'},
#  {'trnOpDate': '20240102',
#   'staCode': '1150',
#   'gateInComingCnt': '1030',
#   'gateOutGoingCnt': '1035'},
#  {'trnOpDate': '20240102',
#   'staCode': '1160',
#   'gateInComingCnt': '3632',
#   'gateOutGoingCnt': '3558'},
#  {'trnOpDate': '20240102',
#   'staCode': '1170',
#   'gateInComingCnt': '5522',
#   'gateOutGoingCnt': '5816'},
#  {'trnOpDate': '20240102',
#   'staCode': '1180',
#   'gateInComingCnt': '6136',
#   'gateOutGoingCnt': '5930'},
#  {'trnOpDate': '20240102',
#   'staCode': '1190',
#   'gateInComingCnt': '2999',
#   'gateOutGoingCnt': '3087'},
#  {'trnOpDate': '20240102',
#   'staCode': '1191',
#   'gateInComingCnt': '251',
#   'gateOutGoingCnt': '314'},
#  {'trnOpDate': '20240102',
#   'staCode': '1192',
#   'gateInComingCnt': '2003',
#   'gateOutGoingCnt': '2354'},
#  {'trnOpDate': '20240102',
#   'staCode': '1193',
#   'gateInComingCnt': '706',
#   'gateOutGoingCnt': '874'},
#  {'trnOpDate': '20240102',
#   'staCode': '1194',
#   'gateInComingCnt': '3773',
#   'gateOutGoingCnt': '3383'},
#  {'trnOpDate': '20240102',
#   'staCode': '1201',
#   'gateInComingCnt': '75',
#   'gateOutGoingCnt': '78'},
#  {'trnOpDate': '20240102',
#   'staCode': '1202',
#   'gateInComingCnt': '228',
#   'gateOutGoingCnt': '160'},
#  {'trnOpDate': '20240102',
#   'staCode': '1203',
#   'gateInComingCnt': '468',
#   'gateOutGoingCnt': '461'},
#  {'trnOpDate': '20240102',
#   'staCode': '1204',
#   'gateInComingCnt': '67',
#   'gateOutGoingCnt': '61'},
#  {'trnOpDate': '20240102',
#   'staCode': '1205',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '41'},
#  {'trnOpDate': '20240102',
#   'staCode': '1206',
#   'gateInComingCnt': '28',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20240102',
#   'staCode': '1207',
#   'gateInComingCnt': '1',
#   'gateOutGoingCnt': '74'},
#  {'trnOpDate': '20240102',
#   'staCode': '1208',
#   'gateInComingCnt': '203',
#   'gateOutGoingCnt': '203'},
#  {'trnOpDate': '20240102',
#   'staCode': '1210',
#   'gateInComingCnt': '18723',
#   'gateOutGoingCnt': '19541'},
#  {'trnOpDate': '20240102',
#   'staCode': '1220',
#   'gateInComingCnt': '1585',
#   'gateOutGoingCnt': '1470'},
#  {'trnOpDate': '20240102',
#   'staCode': '1230',
#   'gateInComingCnt': '664',
#   'gateOutGoingCnt': '629'},
#  {'trnOpDate': '20240102',
#   'staCode': '1240',
#   'gateInComingCnt': '328',
#   'gateOutGoingCnt': '316'},
#  {'trnOpDate': '20240102',
#   'staCode': '1250',
#   'gateInComingCnt': '9014',
#   'gateOutGoingCnt': '8814'},
#  {'trnOpDate': '20240102',
#   'staCode': '2110',
#   'gateInComingCnt': '42',
#   'gateOutGoingCnt': '39'},
#  {'trnOpDate': '20240102',
#   'staCode': '2120',
#   'gateInComingCnt': '87',
#   'gateOutGoingCnt': '98'},
#  {'trnOpDate': '20240102',
#   'staCode': '2130',
#   'gateInComingCnt': '1233',
#   'gateOutGoingCnt': '1286'},
#  {'trnOpDate': '20240102',
#   'staCode': '2140',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20240102',
#   'staCode': '2150',
#   'gateInComingCnt': '488',
#   'gateOutGoingCnt': '451'},
#  {'trnOpDate': '20240102',
#   'staCode': '2160',
#   'gateInComingCnt': '52',
#   'gateOutGoingCnt': '53'},
#  {'trnOpDate': '20240102',
#   'staCode': '2170',
#   'gateInComingCnt': '745',
#   'gateOutGoingCnt': '652'},
#  {'trnOpDate': '20240102',
#   'staCode': '2180',
#   'gateInComingCnt': '1629',
#   'gateOutGoingCnt': '1418'},
#  {'trnOpDate': '20240102',
#   'staCode': '2190',
#   'gateInComingCnt': '275',
#   'gateOutGoingCnt': '275'},
#  {'trnOpDate': '20240102',
#   'staCode': '2200',
#   'gateInComingCnt': '2355',
#   'gateOutGoingCnt': '2027'},
#  {'trnOpDate': '20240102',
#   'staCode': '2210',
#   'gateInComingCnt': '81',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20240102',
#   'staCode': '2220',
#   'gateInComingCnt': '1373',
#   'gateOutGoingCnt': '1120'},
#  {'trnOpDate': '20240102',
#   'staCode': '2230',
#   'gateInComingCnt': '2520',
#   'gateOutGoingCnt': '2447'},
#  {'trnOpDate': '20240102',
#   'staCode': '2240',
#   'gateInComingCnt': '454',
#   'gateOutGoingCnt': '390'},
#  {'trnOpDate': '20240102',
#   'staCode': '2250',
#   'gateInComingCnt': '705',
#   'gateOutGoingCnt': '643'},
#  {'trnOpDate': '20240102',
#   'staCode': '2260',
#   'gateInComingCnt': '1113',
#   'gateOutGoingCnt': '234'},
#  {'trnOpDate': '20240102',
#   'staCode': '3140',
#   'gateInComingCnt': '380',
#   'gateOutGoingCnt': '337'},
#  {'trnOpDate': '20240102',
#   'staCode': '3150',
#   'gateInComingCnt': '883',
#   'gateOutGoingCnt': '914'},
#  {'trnOpDate': '20240102',
#   'staCode': '3160',
#   'gateInComingCnt': '5795',
#   'gateOutGoingCnt': '5961'},
#  {'trnOpDate': '20240102',
#   'staCode': '3170',
#   'gateInComingCnt': '136',
#   'gateOutGoingCnt': '132'},
#  {'trnOpDate': '20240102',
#   'staCode': '3180',
#   'gateInComingCnt': '880',
#   'gateOutGoingCnt': '836'},
#  {'trnOpDate': '20240102',
#   'staCode': '3190',
#   'gateInComingCnt': '704',
#   'gateOutGoingCnt': '610'},
#  {'trnOpDate': '20240102',
#   'staCode': '3210',
#   'gateInComingCnt': '572',
#   'gateOutGoingCnt': '490'},
#  {'trnOpDate': '20240102',
#   'staCode': '3220',
#   'gateInComingCnt': '2269',
#   'gateOutGoingCnt': '2276'},
#  {'trnOpDate': '20240102',
#   'staCode': '3230',
#   'gateInComingCnt': '7336',
#   'gateOutGoingCnt': '6698'},
#  {'trnOpDate': '20240102',
#   'staCode': '3240',
#   'gateInComingCnt': '1014',
#   'gateOutGoingCnt': '903'},
#  {'trnOpDate': '20240102',
#   'staCode': '3250',
#   'gateInComingCnt': '2266',
#   'gateOutGoingCnt': '2258'},
#  {'trnOpDate': '20240102',
#   'staCode': '3260',
#   'gateInComingCnt': '727',
#   'gateOutGoingCnt': '683'},
#  {'trnOpDate': '20240102',
#   'staCode': '3270',
#   'gateInComingCnt': '2561',
#   'gateOutGoingCnt': '2457'},
#  {'trnOpDate': '20240102',
#   'staCode': '3280',
#   'gateInComingCnt': '2147',
#   'gateOutGoingCnt': '2057'},
#  {'trnOpDate': '20240102',
#   'staCode': '3290',
#   'gateInComingCnt': '1346',
#   'gateOutGoingCnt': '1322'},
#  {'trnOpDate': '20240102',
#   'staCode': '3300',
#   'gateInComingCnt': '21815',
#   'gateOutGoingCnt': '22597'},
#  {'trnOpDate': '20240102',
#   'staCode': '3310',
#   'gateInComingCnt': '1785',
#   'gateOutGoingCnt': '1828'},
#  {'trnOpDate': '20240102',
#   'staCode': '3320',
#   'gateInComingCnt': '3333',
#   'gateOutGoingCnt': '3282'},
#  {'trnOpDate': '20240102',
#   'staCode': '3330',
#   'gateInComingCnt': '596',
#   'gateOutGoingCnt': '551'},
#  {'trnOpDate': '20240102',
#   'staCode': '3340',
#   'gateInComingCnt': '6613',
#   'gateOutGoingCnt': '7234'},
#  {'trnOpDate': '20240102',
#   'staCode': '3350',
#   'gateInComingCnt': '633',
#   'gateOutGoingCnt': '1506'},
#  {'trnOpDate': '20240102',
#   'staCode': '3360',
#   'gateInComingCnt': '12228',
#   'gateOutGoingCnt': '11460'},
#  {'trnOpDate': '20240102',
#   'staCode': '3370',
#   'gateInComingCnt': '1138',
#   'gateOutGoingCnt': '1032'},
#  {'trnOpDate': '20240102',
#   'staCode': '3380',
#   'gateInComingCnt': '790',
#   'gateOutGoingCnt': '763'},
#  {'trnOpDate': '20240102',
#   'staCode': '3390',
#   'gateInComingCnt': '7523',
#   'gateOutGoingCnt': '6702'},
#  {'trnOpDate': '20240102',
#   'staCode': '3400',
#   'gateInComingCnt': '535',
#   'gateOutGoingCnt': '488'},
#  {'trnOpDate': '20240102',
#   'staCode': '3410',
#   'gateInComingCnt': '1140',
#   'gateOutGoingCnt': '1044'},
#  {'trnOpDate': '20240102',
#   'staCode': '3420',
#   'gateInComingCnt': '2437',
#   'gateOutGoingCnt': '2095'},
#  {'trnOpDate': '20240102',
#   'staCode': '3430',
#   'gateInComingCnt': '1009',
#   'gateOutGoingCnt': '918'},
#  {'trnOpDate': '20240102',
#   'staCode': '3431',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240102',
#   'staCode': '3432',
#   'gateInComingCnt': '68',
#   'gateOutGoingCnt': '75'},
#  {'trnOpDate': '20240102',
#   'staCode': '3433',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20240102',
#   'staCode': '3434',
#   'gateInComingCnt': '205',
#   'gateOutGoingCnt': '117'},
#  {'trnOpDate': '20240102',
#   'staCode': '3435',
#   'gateInComingCnt': '81',
#   'gateOutGoingCnt': '95'},
#  {'trnOpDate': '20240102',
#   'staCode': '3436',
#   'gateInComingCnt': '54',
#   'gateOutGoingCnt': '87'},
#  {'trnOpDate': '20240102',
#   'staCode': '3450',
#   'gateInComingCnt': '728',
#   'gateOutGoingCnt': '636'},
#  {'trnOpDate': '20240102',
#   'staCode': '3460',
#   'gateInComingCnt': '169',
#   'gateOutGoingCnt': '157'},
#  {'trnOpDate': '20240102',
#   'staCode': '3470',
#   'gateInComingCnt': '5219',
#   'gateOutGoingCnt': '5434'},
#  {'trnOpDate': '20240102',
#   'staCode': '3480',
#   'gateInComingCnt': '1925',
#   'gateOutGoingCnt': '1805'},
#  {'trnOpDate': '20240102',
#   'staCode': '3490',
#   'gateInComingCnt': '129',
#   'gateOutGoingCnt': '111'},
#  {'trnOpDate': '20240102',
#   'staCode': '4050',
#   'gateInComingCnt': '1515',
#   'gateOutGoingCnt': '1734'},
#  {'trnOpDate': '20240102',
#   'staCode': '4060',
#   'gateInComingCnt': '1492',
#   'gateOutGoingCnt': '2117'},
#  {'trnOpDate': '20240102',
#   'staCode': '4070',
#   'gateInComingCnt': '796',
#   'gateOutGoingCnt': '800'},
#  {'trnOpDate': '20240102',
#   'staCode': '4080',
#   'gateInComingCnt': '9066',
#   'gateOutGoingCnt': '8459'},
#  {'trnOpDate': '20240102',
#   'staCode': '4090',
#   'gateInComingCnt': '674',
#   'gateOutGoingCnt': '659'},
#  {'trnOpDate': '20240102',
#   'staCode': '4100',
#   'gateInComingCnt': '165',
#   'gateOutGoingCnt': '144'},
#  {'trnOpDate': '20240102',
#   'staCode': '4110',
#   'gateInComingCnt': '632',
#   'gateOutGoingCnt': '612'},
#  {'trnOpDate': '20240102',
#   'staCode': '4120',
#   'gateInComingCnt': '5156',
#   'gateOutGoingCnt': '4674'},
#  {'trnOpDate': '20240102',
#   'staCode': '4130',
#   'gateInComingCnt': '1009',
#   'gateOutGoingCnt': '997'},
#  {'trnOpDate': '20240102',
#   'staCode': '4140',
#   'gateInComingCnt': '563',
#   'gateOutGoingCnt': '534'},
#  {'trnOpDate': '20240102',
#   'staCode': '4150',
#   'gateInComingCnt': '1296',
#   'gateOutGoingCnt': '1263'},
#  {'trnOpDate': '20240102',
#   'staCode': '4160',
#   'gateInComingCnt': '189',
#   'gateOutGoingCnt': '198'},
#  {'trnOpDate': '20240102',
#   'staCode': '4170',
#   'gateInComingCnt': '3566',
#   'gateOutGoingCnt': '3601'},
#  {'trnOpDate': '20240102',
#   'staCode': '4180',
#   'gateInComingCnt': '1522',
#   'gateOutGoingCnt': '1412'},
#  {'trnOpDate': '20240102',
#   'staCode': '4190',
#   'gateInComingCnt': '2234',
#   'gateOutGoingCnt': '2340'},
#  {'trnOpDate': '20240102',
#   'staCode': '4200',
#   'gateInComingCnt': '2823',
#   'gateOutGoingCnt': '2944'},
#  {'trnOpDate': '20240102',
#   'staCode': '4210',
#   'gateInComingCnt': '3826',
#   'gateOutGoingCnt': '4128'},
#  {'trnOpDate': '20240102',
#   'staCode': '4220',
#   'gateInComingCnt': '22715',
#   'gateOutGoingCnt': '23077'},
#  {'trnOpDate': '20240102',
#   'staCode': '4250',
#   'gateInComingCnt': '1322',
#   'gateOutGoingCnt': '1746'},
#  {'trnOpDate': '20240102',
#   'staCode': '4260',
#   'gateInComingCnt': '733',
#   'gateOutGoingCnt': '788'},
#  {'trnOpDate': '20240102',
#   'staCode': '4270',
#   'gateInComingCnt': '396',
#   'gateOutGoingCnt': '410'},
#  {'trnOpDate': '20240102',
#   'staCode': '4271',
#   'gateInComingCnt': '686',
#   'gateOutGoingCnt': '981'},
#  {'trnOpDate': '20240102',
#   'staCode': '4272',
#   'gateInComingCnt': '2995',
#   'gateOutGoingCnt': '2575'},
#  {'trnOpDate': '20240102',
#   'staCode': '4290',
#   'gateInComingCnt': '1054',
#   'gateOutGoingCnt': '2274'},
#  {'trnOpDate': '20240102',
#   'staCode': '4300',
#   'gateInComingCnt': '1667',
#   'gateOutGoingCnt': '1700'},
#  {'trnOpDate': '20240102',
#   'staCode': '4310',
#   'gateInComingCnt': '2441',
#   'gateOutGoingCnt': '2333'},
#  {'trnOpDate': '20240102',
#   'staCode': '4320',
#   'gateInComingCnt': '1240',
#   'gateOutGoingCnt': '1439'},
#  {'trnOpDate': '20240102',
#   'staCode': '4330',
#   'gateInComingCnt': '2239',
#   'gateOutGoingCnt': '2377'},
#  {'trnOpDate': '20240102',
#   'staCode': '4340',
#   'gateInComingCnt': '10819',
#   'gateOutGoingCnt': '11685'},
#  {'trnOpDate': '20240102',
#   'staCode': '4350',
#   'gateInComingCnt': '799',
#   'gateOutGoingCnt': '769'},
#  {'trnOpDate': '20240102',
#   'staCode': '4360',
#   'gateInComingCnt': '895',
#   'gateOutGoingCnt': '844'},
#  {'trnOpDate': '20240102',
#   'staCode': '4370',
#   'gateInComingCnt': '1470',
#   'gateOutGoingCnt': '1413'},
#  {'trnOpDate': '20240102',
#   'staCode': '4380',
#   'gateInComingCnt': '467',
#   'gateOutGoingCnt': '502'},
#  {'trnOpDate': '20240102',
#   'staCode': '4390',
#   'gateInComingCnt': '657',
#   'gateOutGoingCnt': '676'},
#  {'trnOpDate': '20240102',
#   'staCode': '4400',
#   'gateInComingCnt': '12837',
#   'gateOutGoingCnt': '12506'},
#  {'trnOpDate': '20240102',
#   'staCode': '4410',
#   'gateInComingCnt': '919',
#   'gateOutGoingCnt': '920'},
#  {'trnOpDate': '20240102',
#   'staCode': '4420',
#   'gateInComingCnt': '1750',
#   'gateOutGoingCnt': '1596'},
#  {'trnOpDate': '20240102',
#   'staCode': '4430',
#   'gateInComingCnt': '1457',
#   'gateOutGoingCnt': '1369'},
#  {'trnOpDate': '20240102',
#   'staCode': '4440',
#   'gateInComingCnt': '5467',
#   'gateOutGoingCnt': '4981'},
#  {'trnOpDate': '20240102',
#   'staCode': '4450',
#   'gateInComingCnt': '674',
#   'gateOutGoingCnt': '639'},
#  {'trnOpDate': '20240102',
#   'staCode': '4460',
#   'gateInComingCnt': '1154',
#   'gateOutGoingCnt': '1142'},
#  {'trnOpDate': '20240102',
#   'staCode': '4470',
#   'gateInComingCnt': '173',
#   'gateOutGoingCnt': '168'},
#  {'trnOpDate': '20240102',
#   'staCode': '5000',
#   'gateInComingCnt': '10167',
#   'gateOutGoingCnt': '9556'},
#  {'trnOpDate': '20240102',
#   'staCode': '5010',
#   'gateInComingCnt': '257',
#   'gateOutGoingCnt': '256'},
#  {'trnOpDate': '20240102',
#   'staCode': '5020',
#   'gateInComingCnt': '183',
#   'gateOutGoingCnt': '173'},
#  {'trnOpDate': '20240102',
#   'staCode': '5030',
#   'gateInComingCnt': '957',
#   'gateOutGoingCnt': '900'},
#  {'trnOpDate': '20240102',
#   'staCode': '5040',
#   'gateInComingCnt': '298',
#   'gateOutGoingCnt': '281'},
#  {'trnOpDate': '20240102',
#   'staCode': '5050',
#   'gateInComingCnt': '4051',
#   'gateOutGoingCnt': '3528'},
#  {'trnOpDate': '20240102',
#   'staCode': '5060',
#   'gateInComingCnt': '241',
#   'gateOutGoingCnt': '195'},
#  {'trnOpDate': '20240102',
#   'staCode': '5070',
#   'gateInComingCnt': '546',
#   'gateOutGoingCnt': '565'},
#  {'trnOpDate': '20240102',
#   'staCode': '5080',
#   'gateInComingCnt': '34',
#   'gateOutGoingCnt': '30'},
#  {'trnOpDate': '20240102',
#   'staCode': '5090',
#   'gateInComingCnt': '568',
#   'gateOutGoingCnt': '498'},
#  {'trnOpDate': '20240102',
#   'staCode': '5100',
#   'gateInComingCnt': '195',
#   'gateOutGoingCnt': '174'},
#  {'trnOpDate': '20240102',
#   'staCode': '5110',
#   'gateInComingCnt': '79',
#   'gateOutGoingCnt': '1171'},
#  {'trnOpDate': '20240102',
#   'staCode': '5120',
#   'gateInComingCnt': '1062',
#   'gateOutGoingCnt': '891'},
#  {'trnOpDate': '20240102',
#   'staCode': '5130',
#   'gateInComingCnt': '1091',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20240102',
#   'staCode': '5190',
#   'gateInComingCnt': '185',
#   'gateOutGoingCnt': '179'},
#  {'trnOpDate': '20240102',
#   'staCode': '5200',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20240102',
#   'staCode': '5210',
#   'gateInComingCnt': '657',
#   'gateOutGoingCnt': '660'},
#  {'trnOpDate': '20240102',
#   'staCode': '5220',
#   'gateInComingCnt': '210',
#   'gateOutGoingCnt': '128'},
#  {'trnOpDate': '20240102',
#   'staCode': '5230',
#   'gateInComingCnt': '827',
#   'gateOutGoingCnt': '856'},
#  {'trnOpDate': '20240102',
#   'staCode': '5240',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20240102',
#   'staCode': '6000',
#   'gateInComingCnt': '6718',
#   'gateOutGoingCnt': '4012'},
#  {'trnOpDate': '20240102',
#   'staCode': '6010',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '5'},
#  {'trnOpDate': '20240102',
#   'staCode': '6020',
#   'gateInComingCnt': '265',
#   'gateOutGoingCnt': '158'},
#  {'trnOpDate': '20240102',
#   'staCode': '6030',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '70'},
#  {'trnOpDate': '20240102',
#   'staCode': '6040',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20240102',
#   'staCode': '6050',
#   'gateInComingCnt': '729',
#   'gateOutGoingCnt': '487'},
#  {'trnOpDate': '20240102',
#   'staCode': '6060',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20240102',
#   'staCode': '6070',
#   'gateInComingCnt': '719',
#   'gateOutGoingCnt': '454'},
#  {'trnOpDate': '20240102',
#   'staCode': '6080',
#   'gateInComingCnt': '243',
#   'gateOutGoingCnt': '183'},
#  {'trnOpDate': '20240102',
#   'staCode': '6090',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20240102',
#   'staCode': '6100',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20240102',
#   'staCode': '6110',
#   'gateInComingCnt': '1595',
#   'gateOutGoingCnt': '1178'},
#  {'trnOpDate': '20240102',
#   'staCode': '6120',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240102',
#   'staCode': '6130',
#   'gateInComingCnt': '637',
#   'gateOutGoingCnt': '678'},
#  {'trnOpDate': '20240102',
#   'staCode': '6140',
#   'gateInComingCnt': '44',
#   'gateOutGoingCnt': '41'},
#  {'trnOpDate': '20240102',
#   'staCode': '6150',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '5'},
#  {'trnOpDate': '20240102',
#   'staCode': '6160',
#   'gateInComingCnt': '561',
#   'gateOutGoingCnt': '342'},
#  {'trnOpDate': '20240102',
#   'staCode': '6170',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '42'},
#  {'trnOpDate': '20240102',
#   'staCode': '6180',
#   'gateInComingCnt': '477',
#   'gateOutGoingCnt': '334'},
#  {'trnOpDate': '20240102',
#   'staCode': '6190',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20240102',
#   'staCode': '6200',
#   'gateInComingCnt': '40',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20240102',
#   'staCode': '6210',
#   'gateInComingCnt': '59',
#   'gateOutGoingCnt': '48'},
#  {'trnOpDate': '20240102',
#   'staCode': '6220',
#   'gateInComingCnt': '411',
#   'gateOutGoingCnt': '384'},
#  {'trnOpDate': '20240102',
#   'staCode': '6230',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20240102',
#   'staCode': '6240',
#   'gateInComingCnt': '298',
#   'gateOutGoingCnt': '580'},
#  {'trnOpDate': '20240102',
#   'staCode': '6250',
#   'gateInComingCnt': '676',
#   'gateOutGoingCnt': '622'},
#  {'trnOpDate': '20240102',
#   'staCode': '7000',
#   'gateInComingCnt': '11069',
#   'gateOutGoingCnt': '10157'},
#  {'trnOpDate': '20240102',
#   'staCode': '7010',
#   'gateInComingCnt': '153',
#   'gateOutGoingCnt': '172'},
#  {'trnOpDate': '20240102',
#   'staCode': '7020',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20240102',
#   'staCode': '7030',
#   'gateInComingCnt': '761',
#   'gateOutGoingCnt': '624'},
#  {'trnOpDate': '20240102',
#   'staCode': '7040',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20240102',
#   'staCode': '7050',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '52'},
#  {'trnOpDate': '20240102',
#   'staCode': '7060',
#   'gateInComingCnt': '865',
#   'gateOutGoingCnt': '845'},
#  {'trnOpDate': '20240102',
#   'staCode': '7070',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20240102',
#   'staCode': '7080',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20240102',
#   'staCode': '7090',
#   'gateInComingCnt': '827',
#   'gateOutGoingCnt': '723'},
#  {'trnOpDate': '20240102',
#   'staCode': '7100',
#   'gateInComingCnt': '176',
#   'gateOutGoingCnt': '179'},
#  {'trnOpDate': '20240102',
#   'staCode': '7110',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20240102',
#   'staCode': '7120',
#   'gateInComingCnt': '477',
#   'gateOutGoingCnt': '589'},
#  {'trnOpDate': '20240102',
#   'staCode': '7130',
#   'gateInComingCnt': '663',
#   'gateOutGoingCnt': '700'},
#  {'trnOpDate': '20240102',
#   'staCode': '7150',
#   'gateInComingCnt': '534',
#   'gateOutGoingCnt': '518'},
#  {'trnOpDate': '20240102',
#   'staCode': '7160',
#   'gateInComingCnt': '4542',
#   'gateOutGoingCnt': '4232'},
#  {'trnOpDate': '20240102',
#   'staCode': '7170',
#   'gateInComingCnt': '55',
#   'gateOutGoingCnt': '33'},
#  {'trnOpDate': '20240102',
#   'staCode': '7180',
#   'gateInComingCnt': '143',
#   'gateOutGoingCnt': '141'},
#  {'trnOpDate': '20240102',
#   'staCode': '7190',
#   'gateInComingCnt': '3897',
#   'gateOutGoingCnt': '4218'},
#  {'trnOpDate': '20240102',
#   'staCode': '7200',
#   'gateInComingCnt': '175',
#   'gateOutGoingCnt': '173'},
#  {'trnOpDate': '20240102',
#   'staCode': '7210',
#   'gateInComingCnt': '1977',
#   'gateOutGoingCnt': '1891'},
#  {'trnOpDate': '20240102',
#   'staCode': '7220',
#   'gateInComingCnt': '106',
#   'gateOutGoingCnt': '122'},
#  {'trnOpDate': '20240102',
#   'staCode': '7230',
#   'gateInComingCnt': '1108',
#   'gateOutGoingCnt': '1056'},
#  {'trnOpDate': '20240102',
#   'staCode': '7240',
#   'gateInComingCnt': '64',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20240102',
#   'staCode': '7250',
#   'gateInComingCnt': '68',
#   'gateOutGoingCnt': '54'},
#  {'trnOpDate': '20240102',
# ...
#  {'trnOpDate': '20240104',
#   'staCode': '4400',
#   'gateInComingCnt': '11057',
#   'gateOutGoingCnt': '11438'},
#  {'trnOpDate': '20240104',
#   'staCode': '4410',
#   'gateInComingCnt': '912',
#   'gateOutGoingCnt': '941'},
#  {'trnOpDate': '20240104',
#   'staCode': '4420',
#   'gateInComingCnt': '1633',
#   'gateOutGoingCnt': '1570'},
#  {'trnOpDate': '20240104',
#   'staCode': '4430',
#   'gateInComingCnt': '1464',
#   'gateOutGoingCnt': '1353'},
#  {'trnOpDate': '20240104',
#   'staCode': '4440',
#   'gateInComingCnt': '4839',
#   'gateOutGoingCnt': '4847'},
#  {'trnOpDate': '20240104',
#   'staCode': '4450',
#   'gateInComingCnt': '634',
#   'gateOutGoingCnt': '663'},
#  {'trnOpDate': '20240104',
#   'staCode': '4460',
#   'gateInComingCnt': '1128',
#   'gateOutGoingCnt': '1119'},
#  {'trnOpDate': '20240104',
#   'staCode': '4470',
#   'gateInComingCnt': '165',
#   'gateOutGoingCnt': '163'},
#  {'trnOpDate': '20240104',
#   'staCode': '5000',
#   'gateInComingCnt': '8663',
#   'gateOutGoingCnt': '8658'},
#  {'trnOpDate': '20240104',
#   'staCode': '5010',
#   'gateInComingCnt': '255',
#   'gateOutGoingCnt': '236'},
#  {'trnOpDate': '20240104',
#   'staCode': '5020',
#   'gateInComingCnt': '179',
#   'gateOutGoingCnt': '157'},
#  {'trnOpDate': '20240104',
#   'staCode': '5030',
#   'gateInComingCnt': '785',
#   'gateOutGoingCnt': '830'},
#  {'trnOpDate': '20240104',
#   'staCode': '5040',
#   'gateInComingCnt': '273',
#   'gateOutGoingCnt': '263'},
#  {'trnOpDate': '20240104',
#   'staCode': '5050',
#   'gateInComingCnt': '3186',
#   'gateOutGoingCnt': '3222'},
#  {'trnOpDate': '20240104',
#   'staCode': '5060',
#   'gateInComingCnt': '227',
#   'gateOutGoingCnt': '205'},
#  {'trnOpDate': '20240104',
#   'staCode': '5070',
#   'gateInComingCnt': '494',
#   'gateOutGoingCnt': '489'},
#  {'trnOpDate': '20240104',
#   'staCode': '5080',
#   'gateInComingCnt': '38',
#   'gateOutGoingCnt': '27'},
#  {'trnOpDate': '20240104',
#   'staCode': '5090',
#   'gateInComingCnt': '487',
#   'gateOutGoingCnt': '495'},
#  {'trnOpDate': '20240104',
#   'staCode': '5100',
#   'gateInComingCnt': '146',
#   'gateOutGoingCnt': '155'},
#  {'trnOpDate': '20240104',
#   'staCode': '5110',
#   'gateInComingCnt': '64',
#   'gateOutGoingCnt': '88'},
#  {'trnOpDate': '20240104',
#   'staCode': '5120',
#   'gateInComingCnt': '788',
#   'gateOutGoingCnt': '762'},
#  {'trnOpDate': '20240104',
#   'staCode': '5130',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '40'},
#  {'trnOpDate': '20240104',
#   'staCode': '5160',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20240104',
#   'staCode': '5190',
#   'gateInComingCnt': '195',
#   'gateOutGoingCnt': '192'},
#  {'trnOpDate': '20240104',
#   'staCode': '5200',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20240104',
#   'staCode': '5210',
#   'gateInComingCnt': '704',
#   'gateOutGoingCnt': '683'},
#  {'trnOpDate': '20240104',
#   'staCode': '5220',
#   'gateInComingCnt': '118',
#   'gateOutGoingCnt': '103'},
#  {'trnOpDate': '20240104',
#   'staCode': '5230',
#   'gateInComingCnt': '741',
#   'gateOutGoingCnt': '653'},
#  {'trnOpDate': '20240104',
#   'staCode': '5240',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20240104',
#   'staCode': '6000',
#   'gateInComingCnt': '3343',
#   'gateOutGoingCnt': '3076'},
#  {'trnOpDate': '20240104',
#   'staCode': '6010',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20240104',
#   'staCode': '6020',
#   'gateInComingCnt': '118',
#   'gateOutGoingCnt': '237'},
#  {'trnOpDate': '20240104',
#   'staCode': '6030',
#   'gateInComingCnt': '46',
#   'gateOutGoingCnt': '47'},
#  {'trnOpDate': '20240104',
#   'staCode': '6040',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20240104',
#   'staCode': '6050',
#   'gateInComingCnt': '460',
#   'gateOutGoingCnt': '464'},
#  {'trnOpDate': '20240104',
#   'staCode': '6060',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20240104',
#   'staCode': '6070',
#   'gateInComingCnt': '423',
#   'gateOutGoingCnt': '439'},
#  {'trnOpDate': '20240104',
#   'staCode': '6080',
#   'gateInComingCnt': '137',
#   'gateOutGoingCnt': '198'},
#  {'trnOpDate': '20240104',
#   'staCode': '6090',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '4'},
#  {'trnOpDate': '20240104',
#   'staCode': '6100',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20240104',
#   'staCode': '6110',
#   'gateInComingCnt': '1019',
#   'gateOutGoingCnt': '996'},
#  {'trnOpDate': '20240104',
#   'staCode': '6120',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20240104',
#   'staCode': '6130',
#   'gateInComingCnt': '441',
#   'gateOutGoingCnt': '526'},
#  {'trnOpDate': '20240104',
#   'staCode': '6140',
#   'gateInComingCnt': '37',
#   'gateOutGoingCnt': '46'},
#  {'trnOpDate': '20240104',
#   'staCode': '6150',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20240104',
#   'staCode': '6160',
#   'gateInComingCnt': '375',
#   'gateOutGoingCnt': '348'},
#  {'trnOpDate': '20240104',
#   'staCode': '6170',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '42'},
#  {'trnOpDate': '20240104',
#   'staCode': '6180',
#   'gateInComingCnt': '292',
#   'gateOutGoingCnt': '296'},
#  {'trnOpDate': '20240104',
#   'staCode': '6190',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20240104',
#   'staCode': '6200',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20240104',
#   'staCode': '6210',
#   'gateInComingCnt': '48',
#   'gateOutGoingCnt': '58'},
#  {'trnOpDate': '20240104',
#   'staCode': '6220',
#   'gateInComingCnt': '299',
#   'gateOutGoingCnt': '287'},
#  {'trnOpDate': '20240104',
#   'staCode': '6230',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20240104',
#   'staCode': '6240',
#   'gateInComingCnt': '389',
#   'gateOutGoingCnt': '214'},
#  {'trnOpDate': '20240104',
#   'staCode': '6250',
#   'gateInComingCnt': '475',
#   'gateOutGoingCnt': '437'},
#  {'trnOpDate': '20240104',
#   'staCode': '7000',
#   'gateInComingCnt': '8054',
#   'gateOutGoingCnt': '7811'},
#  {'trnOpDate': '20240104',
#   'staCode': '7010',
#   'gateInComingCnt': '160',
#   'gateOutGoingCnt': '164'},
#  {'trnOpDate': '20240104',
#   'staCode': '7020',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20240104',
#   'staCode': '7030',
#   'gateInComingCnt': '781',
#   'gateOutGoingCnt': '695'},
#  {'trnOpDate': '20240104',
#   'staCode': '7040',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20240104',
#   'staCode': '7050',
#   'gateInComingCnt': '47',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20240104',
#   'staCode': '7060',
#   'gateInComingCnt': '856',
#   'gateOutGoingCnt': '845'},
#  {'trnOpDate': '20240104',
#   'staCode': '7070',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20240104',
#   'staCode': '7080',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20240104',
#   'staCode': '7090',
#   'gateInComingCnt': '816',
#   'gateOutGoingCnt': '780'},
#  {'trnOpDate': '20240104',
#   'staCode': '7100',
#   'gateInComingCnt': '177',
#   'gateOutGoingCnt': '192'},
#  {'trnOpDate': '20240104',
#   'staCode': '7110',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20240104',
#   'staCode': '7120',
#   'gateInComingCnt': '472',
#   'gateOutGoingCnt': '487'},
#  {'trnOpDate': '20240104',
#   'staCode': '7130',
#   'gateInComingCnt': '593',
#   'gateOutGoingCnt': '620'},
#  {'trnOpDate': '20240104',
#   'staCode': '7150',
#   'gateInComingCnt': '491',
#   'gateOutGoingCnt': '495'},
#  {'trnOpDate': '20240104',
#   'staCode': '7160',
#   'gateInComingCnt': '4183',
#   'gateOutGoingCnt': '4049'},
#  {'trnOpDate': '20240104',
#   'staCode': '7170',
#   'gateInComingCnt': '48',
#   'gateOutGoingCnt': '40'},
#  {'trnOpDate': '20240104',
#   'staCode': '7180',
#   'gateInComingCnt': '130',
#   'gateOutGoingCnt': '115'},
#  {'trnOpDate': '20240104',
#   'staCode': '7190',
#   'gateInComingCnt': '3727',
#   'gateOutGoingCnt': '3657'},
#  {'trnOpDate': '20240104',
#   'staCode': '7200',
#   'gateInComingCnt': '146',
#   'gateOutGoingCnt': '132'},
#  {'trnOpDate': '20240104',
#   'staCode': '7210',
#   'gateInComingCnt': '1765',
#   'gateOutGoingCnt': '1852'},
#  {'trnOpDate': '20240104',
#   'staCode': '7220',
#   'gateInComingCnt': '107',
#   'gateOutGoingCnt': '111'},
#  {'trnOpDate': '20240104',
#   'staCode': '7230',
#   'gateInComingCnt': '974',
#   'gateOutGoingCnt': '1026'},
#  {'trnOpDate': '20240104',
#   'staCode': '7240',
#   'gateInComingCnt': '52',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20240104',
#   'staCode': '7250',
#   'gateInComingCnt': '82',
#   'gateOutGoingCnt': '70'},
#  {'trnOpDate': '20240104',
#   'staCode': '7260',
#   'gateInComingCnt': '164',
#   'gateOutGoingCnt': '157'},
#  {'trnOpDate': '20240104',
#   'staCode': '7270',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '67'},
#  {'trnOpDate': '20240104',
#   'staCode': '7280',
#   'gateInComingCnt': '16',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20240104',
#   'staCode': '7290',
#   'gateInComingCnt': '524',
#   'gateOutGoingCnt': '594'},
#  {'trnOpDate': '20240104',
#   'staCode': '7300',
#   'gateInComingCnt': '142',
#   'gateOutGoingCnt': '158'},
#  {'trnOpDate': '20240104',
#   'staCode': '7310',
#   'gateInComingCnt': '654',
#   'gateOutGoingCnt': '640'},
#  {'trnOpDate': '20240104',
#   'staCode': '7320',
#   'gateInComingCnt': '158',
#   'gateOutGoingCnt': '182'},
#  {'trnOpDate': '20240104',
#   'staCode': '7330',
#   'gateInComingCnt': '67',
#   'gateOutGoingCnt': '107'},
#  {'trnOpDate': '20240104',
#   'staCode': '7331',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20240104',
#   'staCode': '7332',
#   'gateInComingCnt': '1775',
#   'gateOutGoingCnt': '1807'},
#  {'trnOpDate': '20240104',
#   'staCode': '7333',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20240104',
#   'staCode': '7334',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '20'},
#  {'trnOpDate': '20240104',
#   'staCode': '7335',
#   'gateInComingCnt': '162',
#   'gateOutGoingCnt': '178'},
#  {'trnOpDate': '20240104',
#   'staCode': '7336',
#   'gateInComingCnt': '165',
#   'gateOutGoingCnt': '140'},
#  {'trnOpDate': '20240104',
#   'staCode': '7350',
#   'gateInComingCnt': '778',
#   'gateOutGoingCnt': '699'},
#  {'trnOpDate': '20240104',
#   'staCode': '7360',
#   'gateInComingCnt': '5797',
#   'gateOutGoingCnt': '6190'},
#  {'trnOpDate': '20240104',
#   'staCode': '7361',
#   'gateInComingCnt': '68',
#   'gateOutGoingCnt': '47'},
#  {'trnOpDate': '20240104',
#   'staCode': '7362',
#   'gateInComingCnt': '130',
#   'gateOutGoingCnt': '218'},
#  {'trnOpDate': '20240104',
#   'staCode': '7380',
#   'gateInComingCnt': '805',
#   'gateOutGoingCnt': '757'},
#  {'trnOpDate': '20240104',
#   'staCode': '7390',
#   'gateInComingCnt': '617',
#   'gateOutGoingCnt': '599'},
#  {'trnOpDate': '20240105',
#   'staCode': '0900',
#   'gateInComingCnt': '10380',
#   'gateOutGoingCnt': '9601'},
#  {'trnOpDate': '20240105',
#   'staCode': '0910',
#   'gateInComingCnt': '1569',
#   'gateOutGoingCnt': '1766'},
#  {'trnOpDate': '20240105',
#   'staCode': '0920',
#   'gateInComingCnt': '3046',
#   'gateOutGoingCnt': '2708'},
#  {'trnOpDate': '20240105',
#   'staCode': '0930',
#   'gateInComingCnt': '7308',
#   'gateOutGoingCnt': '7443'},
#  {'trnOpDate': '20240105',
#   'staCode': '0940',
#   'gateInComingCnt': '3179',
#   'gateOutGoingCnt': '3006'},
#  {'trnOpDate': '20240105',
#   'staCode': '0950',
#   'gateInComingCnt': '2868',
#   'gateOutGoingCnt': '2272'},
#  {'trnOpDate': '20240105',
#   'staCode': '0960',
#   'gateInComingCnt': '12492',
#   'gateOutGoingCnt': '12897'},
#  {'trnOpDate': '20240105',
#   'staCode': '0970',
#   'gateInComingCnt': '14727',
#   'gateOutGoingCnt': '14561'},
#  {'trnOpDate': '20240105',
#   'staCode': '0980',
#   'gateInComingCnt': '16462',
#   'gateOutGoingCnt': '18122'},
#  {'trnOpDate': '20240105',
#   'staCode': '0990',
#   'gateInComingCnt': '21400',
#   'gateOutGoingCnt': '21626'},
#  {'trnOpDate': '20240105',
#   'staCode': '1000',
#   'gateInComingCnt': '70365',
#   'gateOutGoingCnt': '66668'},
#  {'trnOpDate': '20240105',
#   'staCode': '1010',
#   'gateInComingCnt': '5604',
#   'gateOutGoingCnt': '5563'},
#  {'trnOpDate': '20240105',
#   'staCode': '1020',
#   'gateInComingCnt': '26543',
#   'gateOutGoingCnt': '26782'},
#  {'trnOpDate': '20240105',
#   'staCode': '1030',
#   'gateInComingCnt': '4119',
#   'gateOutGoingCnt': '3856'},
#  {'trnOpDate': '20240105',
#   'staCode': '1040',
#   'gateInComingCnt': '15595',
#   'gateOutGoingCnt': '15985'},
#  {'trnOpDate': '20240105',
#   'staCode': '1050',
#   'gateInComingCnt': '1634',
#   'gateOutGoingCnt': '1609'},
#  {'trnOpDate': '20240105',
#   'staCode': '1060',
#   'gateInComingCnt': '1998',
#   'gateOutGoingCnt': '1936'},
#  {'trnOpDate': '20240105',
#   'staCode': '1070',
#   'gateInComingCnt': '9900',
#   'gateOutGoingCnt': '10088'},
#  {'trnOpDate': '20240105',
#   'staCode': '1080',
#   'gateInComingCnt': '30288',
#   'gateOutGoingCnt': '31493'},
#  {'trnOpDate': '20240105',
#   'staCode': '1090',
#   'gateInComingCnt': '11543',
#   'gateOutGoingCnt': '10988'},
#  {'trnOpDate': '20240105',
#   'staCode': '1100',
#   'gateInComingCnt': '27717',
#   'gateOutGoingCnt': '26655'},
#  {'trnOpDate': '20240105',
#   'staCode': '1110',
#   'gateInComingCnt': '7204',
#   'gateOutGoingCnt': '7042'},
#  {'trnOpDate': '20240105',
#   'staCode': '1120',
#   'gateInComingCnt': '6607',
#   'gateOutGoingCnt': '5691'},
#  {'trnOpDate': '20240105',
#   'staCode': '1130',
#   'gateInComingCnt': '1871',
#   'gateOutGoingCnt': '2049'},
#  {'trnOpDate': '20240105',
#   'staCode': '1140',
#   'gateInComingCnt': '420',
#   'gateOutGoingCnt': '455'},
#  {'trnOpDate': '20240105',
#   'staCode': '1150',
#   'gateInComingCnt': '1111',
#   'gateOutGoingCnt': '1069'},
#  {'trnOpDate': '20240105',
#   'staCode': '1160',
#   'gateInComingCnt': '4238',
#   'gateOutGoingCnt': '4116'},
#  {'trnOpDate': '20240105',
#   'staCode': '1170',
#   'gateInComingCnt': '6839',
#   'gateOutGoingCnt': '6206'},
#  {'trnOpDate': '20240105',
#   'staCode': '1180',
#   'gateInComingCnt': '6826',
#   'gateOutGoingCnt': '6756'},
#  {'trnOpDate': '20240105',
#   'staCode': '1190',
#   'gateInComingCnt': '3529',
#   'gateOutGoingCnt': '3518'},
#  {'trnOpDate': '20240105',
#   'staCode': '1191',
#   'gateInComingCnt': '351',
#   'gateOutGoingCnt': '320'},
#  {'trnOpDate': '20240105',
#   'staCode': '1192',
#   'gateInComingCnt': '2987',
#   'gateOutGoingCnt': '2364'},
#  {'trnOpDate': '20240105',
#   'staCode': '1193',
#   'gateInComingCnt': '1038',
#   'gateOutGoingCnt': '798'},
#  {'trnOpDate': '20240105',
#   'staCode': '1194',
#   'gateInComingCnt': '3974',
#   'gateOutGoingCnt': '4723'},
#  {'trnOpDate': '20240105',
#   'staCode': '1201',
#   'gateInComingCnt': '69',
#   'gateOutGoingCnt': '82'},
#  {'trnOpDate': '20240105',
#   'staCode': '1202',
#   'gateInComingCnt': '243',
#   'gateOutGoingCnt': '186'},
#  {'trnOpDate': '20240105',
#   'staCode': '1203',
#   'gateInComingCnt': '526',
#   'gateOutGoingCnt': '533'},
#  {'trnOpDate': '20240105',
#   'staCode': '1204',
#   'gateInComingCnt': '74',
#   'gateOutGoingCnt': '75'},
#  {'trnOpDate': '20240105',
#   'staCode': '1205',
#   'gateInComingCnt': '40',
#   'gateOutGoingCnt': '43'},
#  {'trnOpDate': '20240105',
#   'staCode': '1206',
#   'gateInComingCnt': '28',
#   'gateOutGoingCnt': '31'},
#  {'trnOpDate': '20240105',
#   'staCode': '1207',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '87'},
#  {'trnOpDate': '20240105',
#   'staCode': '1208',
#   'gateInComingCnt': '208',
#   'gateOutGoingCnt': '227'},
#  {'trnOpDate': '20240105',
#   'staCode': '1210',
#   'gateInComingCnt': '22465',
#   'gateOutGoingCnt': '21393'},
#  {'trnOpDate': '20240105',
#   'staCode': '1220',
#   'gateInComingCnt': '1759',
#   'gateOutGoingCnt': '1500'},
#  {'trnOpDate': '20240105',
#   'staCode': '1230',
#   'gateInComingCnt': '702',
#   'gateOutGoingCnt': '720'},
#  {'trnOpDate': '20240105',
#   'staCode': '1240',
#   'gateInComingCnt': '299',
#   'gateOutGoingCnt': '311'},
#  {'trnOpDate': '20240105',
#   'staCode': '1250',
#   'gateInComingCnt': '9955',
#   'gateOutGoingCnt': '10497'},
#  {'trnOpDate': '20240105',
#   'staCode': '2110',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '37'},
#  {'trnOpDate': '20240105',
#   'staCode': '2120',
#   'gateInComingCnt': '87',
#   'gateOutGoingCnt': '114'},
#  {'trnOpDate': '20240105',
#   'staCode': '2130',
#   'gateInComingCnt': '2010',
#   'gateOutGoingCnt': '1264'},
#  {'trnOpDate': '20240105',
#   'staCode': '2140',
#   'gateInComingCnt': '65',
#   'gateOutGoingCnt': '30'},
#  {'trnOpDate': '20240105',
#   'staCode': '2150',
#   'gateInComingCnt': '454',
#   'gateOutGoingCnt': '543'},
#  ...]

# %%
#truOpData(乘車日)、staCode(車站代碼)、gateInComimgCnt(進站人數)、gateOutGoingCnt(出站人數)

# %%
url2 = 'https://ods.railway.gov.tw/tra-ods-web/ods/download/dataResource/0518b833e8964d53bfea3f7691aea0ee'
