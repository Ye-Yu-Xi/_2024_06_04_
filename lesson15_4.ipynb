# %%
# 15-4課堂: pandas模組 / API reference / 資料類型:Serious DataFrame
#pandas.Serious   Serious是class

# %%
# https://pandas.pydata.org/docs/reference/index.html

# %%
import numpy as np

student = np.array([67, 78, 92, 74, 65])
student[0]
student[4]
# Out:
# np.int64(65)

# %%
import pandas as pd
#筆記:原生索引 [0,  1,   2,  3,  4]
s1 =pd.Series([67, 78, 92, 74, 65],index=['國文', '英文', '數學', '地理', '歷史',])  #新增key索引
s1
# Out:
# 國文    67
# 英文    78
# 數學    92
# 地理    74
# 歷史    65
# dtype: int64

# %%
s1 + 3   #承上，直接把每個數字加3
# Out:
# 國文    70
# 英文    81
# 數學    95
# 地理    77
# 歷史    68
# dtype: int64

# %%
s1['國文'] #使用key-index
s1[0]  #使用原生-index
# Out:
# /tmp/ipykernel_631/2433701864.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]  #使用原生-index
# np.int64(67)

# %%
for i in s1:
    print(i)
# Out:
# 67
# 78
# 92
# 74
# 65

# %%
#numpy的統計,可以套用在pandas
s1
# Out:
# 國文    67
# 英文    78
# 數學    92
# 地理    74
# 歷史    65
# dtype: int64

# %%
#利用numpy的function做統計
np.sum(s1)
# Out:
# np.int64(376)

# %%
np.mean(s1) #平均數
# Out:
# np.float64(75.2)

# %%
np.std(s1) #標準差
# Out:
# np.float64(9.620810776644555)

# %%
np.median(s1)  #中位數
# Out:
# np.float64(74.0)

# %%
import pandas as pd
pd.DataFrame({
    "徐國堂":[78 , 92, 76, 91, 72],  #裡面是dictionary資料結構
    "王XX":[72 , 81, 92, 94, 69],
    "張XX":[81 , 65, 89, 81, 72],
},index=['國文', '英文', '數學', '地理', '歷史'])
# Out:
#     徐國堂  王XX  張XX
# 國文   78   72   81
# 英文   92   81   65
# 數學   76   92   89
# 地理   91   94   81
# 歷史   72   69   72

# %%
import numpy as np
import pandas as pd

data = np.random.randint(60,high=100,size=(50,5))
pd.DataFrame(data,
             index = range(1,51),
             columns=['國文', '英文', '數學', '地理', '歷史']  #
             )
# Out:
#     國文  英文  數學  地理  歷史
# 1   92  79  99  83  63
# 2   60  77  83  68  93
# 3   89  67  72  93  91
# 4   76  81  68  79  62
# 5   80  87  89  64  89
# 6   81  94  75  70  67
# 7   98  67  90  64  95
# 8   96  80  83  74  68
# 9   91  78  89  62  77
# 10  96  62  79  97  75
# 11  92  62  61  87  68
# 12  77  82  98  81  90
# 13  75  80  95  63  66
# 14  74  93  80  96  63
# 15  98  91  79  70  80
# 16  70  94  78  75  73
# 17  70  91  67  74  80
# 18  76  98  69  66  95
# 19  96  73  84  68  84
# 20  78  77  73  78  84
# 21  84  81  72  74  89
# 22  75  98  90  89  99
# 23  69  85  64  75  61
# 24  78  99  74  68  87
# 25  77  67  98  85  93
# 26  96  92  75  83  85
# 27  65  62  93  69  77
# 28  98  87  60  76  78
# 29  95  99  76  82  66
# 30  90  66  84  78  98
# 31  63  76  92  66  75
# 32  94  64  78  78  99
# 33  69  68  77  62  97
# 34  61  80  62  95  99
# 35  61  96  70  61  80
# 36  88  93  62  85  82
# 37  76  83  95  87  62
# 38  75  97  73  95  97
# 39  87  94  69  88  72
# 40  85  63  90  68  89
# 41  87  69  77  92  70
# 42  97  83  67  67  96
# 43  61  97  61  71  85
# 44  65  88  98  79  90
# 45  84  93  92  80  72
# 46  96  94  73  62  62
# 47  60  77  66  99  69
# 48  63  61  61  60  95
# 49  99  96  65  66  71
# 50  85  89  90  89  63
