# %%
#google搜尋:matplotli python install    https://matplotlib.org/stable/install/index.html

# %%
#標準寫法      #1:58:24~2:12:00觀念講解
import matplotlib.pyplot as plt      # matplotlib.pyplot名字太長 定義(as)一個小名plt 以後就叫這個小名

#1.製作figure        #UC筆記：figure=畫布
fig = plt.figure()

# 2在1.的figure上製作一個axes      #UC筆記：axes=圖表
ax_1 = fig.add_subplot(1, 1, 1)   #figure裡有1個圖表(1列,1欄,會傳出第1個圖表)  #2:09:32

# 3將圖的數據儲存在axes中      #UC筆記：X-axis Y-axis = X軸,Y軸
X= [5,3,9]       
Y= [3,4,5]
ax_1.plot(X,Y)      #UC筆記:左邊代表 X(5)對應Y(3) / X(3)對應Y(4) / X(9)對應Y(5)

# 4.顯示圖
plt.show()

# %%
# Axes.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#UC筆記: *args =沒有限定數量的引數值呼叫 ex:2,4,6,8    **kwargs=沒有限定引數名稱的呼叫 ex: n=4,j =8

# %%
#2:16:20
figure = plt.figure()
xes
